# %% [markdown]
# ### RAG Pipleline Data Ingestion to Vector DB Pipeline

# %%
import os
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pathlib import Path

# %%
# read all pdf's from the directory
def process_all_pdfs(pdf_directory):
    """Process all PDF files in a directory"""
    all_documents = []
    pdf_dir = Path(pdf_directory)

    # Find all PDF files recursively
    pdf_files = list(pdf_dir.glob("**/*.pdf"))

    print(f"Found {len(pdf_files)} PDF files to process")

    for pdf_file in pdf_files:
        print(f"\nProcessing: {pdf_file.name}")
        try:
            loader = PyPDFLoader(str(pdf_file))
            documents = loader.load()

            # add source information to metadata
            for doc in documents:
                doc.metadata["source_file"] = pdf_file.name
                doc.metadata["file_type"] = "pdf"

            all_documents.extend(documents)
            print(f"Loaded {len(documents)} pages")

        except Exception as e:
            print(f"Error: {e}")

    print(f"\nTotol documents loaded: {len(all_documents)}")
    return all_documents

# process all pdfs in the data directory 
all_pdf_documents = process_all_pdfs("../notebook")
# Out:
# Found 1 PDF files to process
#
# Processing: The_RAG_Systems_Schematic.pdf
# Loaded 13 pages
#
# Totol documents loaded: 13

# %%
all_pdf_documents
# Out:
# [Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': '..\\notebook\\The_RAG_Systems_Schematic.pdf', 'total_pages': 13, 'page': 0, 'page_label': '1', 'source_file': 'The_RAG_Systems_Schematic.pdf', 'file_type': 'pdf'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': '..\\notebook\\The_RAG_Systems_Schematic.pdf', 'total_pages': 13, 'page': 1, 'page_label': '2', 'source_file': 'The_RAG_Systems_Schematic.pdf', 'file_type': 'pdf'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': '..\\notebook\\The_RAG_Systems_Schematic.pdf', 'total_pages': 13, 'page': 2, 'page_label': '3', 'source_file': 'The_RAG_Systems_Schematic.pdf', 'file_type': 'pdf'}, page_content=''),
# ...

# %%
def process_all_pdfs(pdf_directory):
    """process all the pdf documents"""
    all_documents = []
    pdf_dir = Path(pdf_directory)

    pdf_files = list(pdf_dir.glob("**/*.pdf"))
    print(pdf_files)
    print(len(pdf_files))

    for pdf_file in pdf_files:
        print("\n",pdf_file.name)

        try:
            loader = PyMuPDFLoader(str(pdf_file))
            documents = loader.load()

            for doc in documents:
                doc.metadata["source_file"] = pdf_file.name
                doc.metadata["file_type"] = "pdf"

            all_documents.extend(documents)
            print(len(documents))

        except Exception as e:
            print("Error",e)

    print("\nTotal documents loaded:",len(all_documents))
    return all_documents
 
all_pdf_documents = process_all_pdfs("../notebook")
# Out:
# [WindowsPath('../notebook/The_RAG_Systems_Schematic.pdf')]
# 1
#
#  The_RAG_Systems_Schematic.pdf
# 13
#
# Total documents loaded: 13
