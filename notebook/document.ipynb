# %% [markdown]
# ### Data ingestion

# %% [markdown]
# ### documnet datastructure
# - page-content : what conttent page have
# - metadata : it like extra information for eg : author , no. of pages

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is main page contain I am using to create RAG",
    metadata= {
        "source" :"example.txt",
        "pages":1,
        "author":"Krish naik",
        "date_created":"2026-06-15"
    }
)

doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Krish naik', 'date_created': '2026-06-15'}, page_content='This is main page contain I am using to create RAG')

# %%
## Create a simple txt file

import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/python_intro.txt":"""Python is a high-level, interpreted programming language known for its clear syntax and exceptional readability. Created by Guido van Rossum and first released in 1991, it has become one of the most popular languages in the world. It supports multiple programming paradigms, including object-oriented, procedural, and functional programming.Key Features of PythonSimple Syntax: Reads similarly to plain English.Dynamically Typed: Variables do not require explicit type declaration.Interpreted: Code executes line-by-line immediately without prior compilation.Cross-Platform: Runs seamlessly on Windows, macOS, Linux, and Raspberry Pi.Large Ecosystem: Packed with massive standard and third-party libraries.Core Concepts1. Your First ProgramPython uses the print() function to display text to the console. Comments are created using the # symbol.python# This is a comment and will be ignored by Python
print("Hello, World!"). 
""",
    "../data/text_files/machine_learning.txt" : """Machine learning (ML) is a subset of artificial intelligence (AI) that enables computers to learn from data and make predictions without being explicitly programmed. Instead of writing hard-coded instructions, ML models identify patterns in data to autonomously solve tasks ranging from medical diagnostics to spam filtering."""

}

for filepath,content in sample_texts.items():
    with open(filepath,"w",encoding="utf-8") as f:
        f.write(content)

print("Sample text files created")
# Out:
# Sample text files created

# %%
### how to read those files
# TextLoader

from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python is a high-level, interpreted programming language known for its clear syntax and exceptional readability. Created by Guido van Rossum and first released in 1991, it has become one of the most popular languages in the world. It supports multiple programming paradigms, including object-oriented, procedural, and functional programming.Key Features of PythonSimple Syntax: Reads similarly to plain English.Dynamically Typed: Variables do not require explicit type declaration.Interpreted: Code executes line-by-line immediately without prior compilation.Cross-Platform: Runs seamlessly on Windows, macOS, Linux, and Raspberry Pi.Large Ecosystem: Packed with massive standard and third-party libraries.Core Concepts1. Your First ProgramPython uses the print() function to display text to the console. Comments are created using the # symbol.python# This is a comment and will be ignored by Python\nprint("Hello
# ...

# %%
# Directory Loader     (to see all files from directory)

from langchain_community.document_loaders import DirectoryLoader

dir_Loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",  ## pattern to match files
    loader_kwargs={"encoding": "utf-8"},
    loader_cls=TextLoader,
    show_progress=False
)

documents = dir_Loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine learning (ML) is a subset of artificial intelligence (AI) that enables computers to learn from data and make predictions without being explicitly programmed. Instead of writing hard-coded instructions, ML models identify patterns in data to autonomously solve tasks ranging from medical diagnostics to spam filtering.'),
# ...

# %% [markdown]
# from langchain_community.document_loaders import TextLoader
# loader = TextLoader(".......",encoding="UTF-8")
# document = loader.load()
# print(document)
#
# from langchian_community.document_loaders import TextLoader
# loader = TextLoader("...",encoding="UTF-8")
# documnet=loader.load()
# print(document)
#
#
# <!-- directoryloader --> to see all files from directory
#
# from langchain_community.document_loaders import DirectoryLoader
#
# dir_loader = DiretoryLoader(
#     "../data/text_files",
#     glob ="**/*.text", pattern to match files
#     loader_cls = TextLoader,
#     loader_kwargs = {"encoding" :"utf-8"},
#     show_progress = True
# )
#
# documents = dir_loader.load()
# documents

# %%
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_loaders import DirectoryLoader


# load all pdf files from the directory

dir_Loaders = DirectoryLoader(
    "../data/",
    glob= "**/*.pdf",
    loader_cls= PyMuPDFLoader,
    show_progress=False
)

pdf_documents = dir_Loaders.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-05-11T23:08:03+05:30', 'source': '..\\data\\DDRAUTRESUME.pdf', 'file_path': '..\\data\\DDRAUTRESUME.pdf', 'total_pages': 1, 'format': 'PDF 1.7', 'title': '', 'author': 'Un-named', 'subject': '', 'keywords': '', 'moddate': '2026-05-11T23:08:03+05:30', 'trapped': '', 'modDate': "D:20260511230803+05'30'", 'creationDate': "D:20260511230803+05'30'", 'page': 0}, page_content='DIVYA RAUT \nData Science | Data Analyst \ndivyaraut5001@gmail.com | 8669806028 \nwww.linkedin.com/in/divya-raut-760a083aa | https://github.com/dataraftai   \nPROFESSIONAL SUMMARY  \nData Analyst with hands-on experience in SQL-based data cleaning, transformation, and exploratory analysis across \nmultiple domains (real estate, customer analytics, healthcare data). Skilled at examining datasets for inconsistencies, \nvalidating assumptions before drawing conclusions, and preparing reliable analytical materi
# ...
